# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
int = [478, 101, 235, 605, 1318, 757, 920, 986, 750]
shs = [310, 37, 114, 402, 973, 550, 679, 754, 531]
bg = 17

shs_=[x-bg for x in shs]
int_ = [x**2 for x in int]

coef = []
for i in range(len(shs)):
    coef.append(shs_[i]/int_[i])

# %%
shs_
# Out:
# [293, 20, 97, 385, 956, 533, 662, 737, 514]

# %%
plt.loglog(int, shs_, 'o')

# %%
cm,b = np.polyfit(intlog, shslog, 1)

# %%
intlog = np.log(int_)
shslog = np.log(shs)

# %%
cm
# Out:
# np.float64(0.6499440881854469)

# %%
b
# Out:
# np.float64(-2.3492863158191044)

# %%
plt.scatter(intlog, shslog)
